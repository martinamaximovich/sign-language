# %% [markdown]
# mm5775 Martina Maximovich

# %% [markdown]
# # MNIST Sign Language

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics         import accuracy_score
from sklearn.model_selection import train_test_split

import keras
from keras.utils  import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# %%
class SignLanguage:
    def __init__(self):
        self.model = None
        
        self.data = {
            "train": None,
            "test" : None
        }
        self.create_model()
    
    def create_model(self):
        """
        Create a CNN model and save it to self.model
        """
        
        # TODO: Create a Sequential model
        model = Sequential() 
        model.add(Conv2D(filters=32, kernel_size=(3 , 3), strides = 1, padding = 'same' , activation = 'relu' , input_shape = (28,28,1)))
        model.add(MaxPooling2D((2, 2)))
        model.add(Conv2D(64, (3, 3), activation='relu'))
        model.add(MaxPooling2D((2, 2)))
        model.add(Conv2D(64, (3, 3), activation='relu'))
        model.add(Conv2D(64, (3, 3), activation='relu'))
        model.add(Flatten())
        model.add(Dense(64, activation='relu'))
        model.add(Dense(25, activation='softmax'))
        #used tenserflow documentation @ https://www.tensorflow.org/tutorials/images/cnn

        # TODO: Compile the model with categorical_crossentropy
        model.compile('adam', loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])
        
        self.model = model
    
    def prepare_data(self, images, labels):
        """
        Use this method to normalize the dataset and split it into train/test.
        Save your data in self.data["train"] and self.data["test"] as a tuple
        of (images, labels)
        
        :param images numpy array of size (num_examples, 28*28)
        :param labels numpy array of size (num_examples, )
        """
        # TODO : split into training and validation set
        # TODO : reshape each example into a 2D image (28, 28, 1)

        images = images / 255.0
        labels = to_categorical(labels)
        
        x_train, x_test, y_train, y_test=train_test_split(images, labels, test_size=0.5, random_state=20)
        x_train, x_test = x_train.reshape(x_train.shape[0], 28, 28, 1), x_test.reshape(x_test.shape[0], 28, 28, 1)

        self.data = {
            "train": (x_train, y_train), # (x_train, y_train)
            "test" : (x_test, y_test) # (x_test, y_test)
        }

        pass
    
    def train(self, batch_size:int=128, epochs:int=50, verbose:int=1):
        """
        Use model.fit() to train your model. Make sure to return the history for a neat visualization.
        
        :param batch_size The batch size to use for training
        :param epochs     Number of epochs to use for training
        :param verbose    Whether or not to print training output
        """
        
        #history = self.model.fit(batch_size=batch_size, epochs=epochs, verbose=verbose, train_images, train_labels, epochs=epochs, 
                    #validation_data=(test_images, test_labels))
        
        history = self.model.fit(*self.data["train"], validation_data = self.data["test"], batch_size=batch_size, epochs=epochs, verbose=verbose)
        return history
    
    def predict(self, data):
        """
        Use the trained model to predict labels for test data.
        
        :param data: numpy array of test images
        :return a numpy array of test labels. array size = (num_examples, )
        """
        data = data / 255.0
        data = data.reshape(data.shape[0], 28, 28, 1)

        predicted = self.model.predict(data)
        labels = np.argmax(predicted, axis=1)

        return labels
        # Don't forget to normalize the data in the same way as training data
        # self.model.predict() and np.argmax( , axis=1) might help
        

        #self.model.predict()
        #return np.zeros(data.shape[0])
    
    def visualize_data(self, data):
        """
        Visualizing the hand gestures
        
        :param data: numpy array of images
        """
        if data is None: return
        
        nrows, ncols = 5, 5
        fig, axs = plt.subplots(nrows, ncols, figsize=(10, 10), sharex=True, sharey=True)
        plt.subplots_adjust(wspace=0, hspace=0)

        for i in range(nrows):
            for j in range(ncols):
                axs[i][j].imshow(data[0][i*ncols+j].reshape(28, 28), cmap='gray')
        plt.show()

    def visualize_accuracy(self, history):
        """
        Plots out the accuracy measures given a keras history object
        
        :param history: return value from model.fit()
        """
        if history is None: return
        
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title("Accuracy")
        plt.xlabel('epoch')
        plt.ylabel('accuracy')
        plt.legend(['train','test'])
        plt.show()

# %% [markdown]
# # Grading Script
#
# Do NOT modify this section

# %%
if __name__=="__main__":
    train = pd.read_csv('train.csv')
    test  = pd.read_csv('test.csv')

    train_labels, test_labels = train['label'].values, test['label'].values
    train.drop('label', axis=1, inplace=True)
    test.drop('label', axis=1, inplace=True)

    num_classes = test_labels.max() + 1
    train_images, test_images = train.values, test.values

    print(train_images.shape, train_labels.shape, test_images.shape, test_labels.shape)
# Out:
# (27455, 784) (27455,) (7172, 784) (7172,)

# %%
if __name__=="__main__":
    my_model = SignLanguage()
    my_model.prepare_data(train_images, train_labels)

# %%
if __name__=="__main__":
    my_model.visualize_data(my_model.data["train"])

# %%
if __name__=="__main__":
    history = my_model.train(epochs=30, verbose=1)
    my_model.visualize_accuracy(history)
# Out:
# Epoch 1/30
# 108/108 [==============================] - 2s 14ms/step - loss: 2.7739 - accuracy: 0.1596 - val_loss: 1.8373 - val_accuracy: 0.4158
# Epoch 2/30
# 108/108 [==============================] - 1s 9ms/step - loss: 1.3294 - accuracy: 0.5741 - val_loss: 0.9577 - val_accuracy: 0.6871
# Epoch 3/30
# 108/108 [==============================] - 1s 12ms/step - loss: 0.6912 - accuracy: 0.7719 - val_loss: 0.5023 - val_accuracy: 0.8328
# Epoch 4/30
# 108/108 [==============================] - 1s 9ms/step - loss: 0.3765 - accuracy: 0.8754 - val_loss: 0.2660 - val_accuracy: 0.9205
# Epoch 5/30
# 108/108 [==============================] - 1s 12ms/step - loss: 0.1925 - accuracy: 0.9426 - val_loss: 0.1376 - val_accuracy: 0.9623
# Epoch 6/30
# 108/108 [==============================] - 1s 11ms/step - loss: 0.1067 - accuracy: 0.9704 - val_loss: 0.0882 - val_accuracy: 0.9757
# Epoch 7/30
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0727 - accuracy: 0.9826 - val_loss: 0.0430 - val_accuracy: 0.9935
# Epoch 8/30
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0351 - accuracy: 0.9932 - val_loss: 0.0515 - val_accuracy: 0.9852
# Epoch 9/30
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0240 - accuracy: 0.9958 - val_loss: 0.0224 - val_accuracy: 0.9962
# Epoch 10/30
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0144 - accuracy: 0.9982 - val_loss: 0.0221 - val_accuracy: 0.9932
# Epoch 11/30
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0164 - accuracy: 0.9972 - val_loss: 0.0112 - val_accuracy: 0.9983
# Epoch 12/30
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0063 - accuracy: 0.9995 - val_loss: 0.0060 - val_accuracy: 0.9997
# Epoch 13/30
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0113 - accuracy: 0.9978 - val_loss: 0.0115 - val_accuracy: 0.9973
# Epoch 14/30
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0032 - accuracy: 0.9999 - val_loss: 0.0035 - val_accuracy: 0.9996
# Epoch 15/30
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 0.9997
# Epoch 16/30
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 0.9998
# Epoch 17/30
# 108/108 [==============================] - 1s 9ms/step - loss: 9.3312e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 0.9998
# Epoch 18/30
# 108/108 [==============================] - 1s 9ms/step - loss: 8.6783e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 0.9996
# Epoch 19/30
# 108/108 [==============================] - 1s 9ms/step - loss: 6.5744e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 0.9996
# Epoch 20/30
# 108/108 [==============================] - 1s 12ms/step - loss: 5.9863e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 0.9997
# Epoch 21/30
# 108/108 [==============================] - 1s 9ms/step - loss: 5.6012e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 0.9998
# Epoch 22/30
# 108/108 [==============================] - 1s 9ms/step - loss: 4.5862e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 0.9998
# Epoch 23/30
# 108/108 [==============================] - 1s 9ms/step - loss: 4.0139e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 0.9998
# Epoch 24/30
# 108/108 [==============================] - 1s 11ms/step - loss: 3.7505e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 0.9997
# Epoch 25/30
# 108/108 [==============================] - 1s 9ms/step - loss: 3.1485e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 0.9997
# Epoch 26/30
# 108/108 [==============================] - 1s 12ms/step - loss: 3.0418e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 0.9999
# Epoch 27/30
# 108/108 [==============================] - 1s 9ms/step - loss: 2.6528e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 0.9997
# Epoch 28/30
# 108/108 [==============================] - 1s 9ms/step - loss: 2.4800e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 0.9998
# Epoch 29/30
# 108/108 [==============================] - 1s 12ms/step - loss: 2.2204e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 0.9997
# Epoch 30/30
# 108/108 [==============================] - 1s 9ms/step - loss: 2.0419e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 0.9997

# %%
if __name__=="__main__":
    y_pred = my_model.predict(test_images)
    accuracy = accuracy_score(test_labels, y_pred)
    print(accuracy)
# Out:
# 225/225 [==============================] - 1s 2ms/step
# 0.9192693809258227
